# %% [markdown]
# <a href="https://colab.research.google.com/github/ilirsheraj/DUDL/blob/main/Chapter_03_Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
from IPython import display
# Create pictures in vector format: Higher resolution
display.set_matplotlib_formats("svg")

# %% [markdown]
# ## Gradient Descent in 1D

# %%
# Create two functions, for function and its derivative
def fx(x):
  return 3*x**2 - 3*x + 4

# derivative of the function
def deriv(x):
  return 6*x - 3

# %%
# Plot both functions over a range of values
x = np.linspace(-2,2,2001)

plt.plot(x, fx(x), x, deriv(x))
plt.xlim([-2,2])
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend(["y", "dy"])
plt.show()

# %%
# Lets define a random starting point
localmin = np.random.choice(x,1)
print(localmin)

# define learning parameters
learning_rate = 0.01
training_epochs = 100

# Run through a training session
for i in range(training_epochs):
  # take the derivative
  grad = deriv(localmin)
  # update the value of the local minima
  localmin = localmin - learning_rate*grad

print(localmin)
# Out:
# [1.15]
# [0.50133567]

# %%
 # Plot the results
plt.plot(x, fx(x), x, deriv(x))
plt.plot(localmin, deriv(localmin),"ro")
plt.plot(localmin, fx(localmin), "ro")

plt.xlim([-2,2])
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend(["f(x)", "df", "f(x) min"])
plt.title("Emipirical local minimum is {:.3f}".format(localmin[0]))
plt.show()

# %%
# Lets store the parameters
localmin = np.random.choice(x,1)
modelparams = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad
  modelparams[i,:] = localmin, grad

modelparams[:5,:]
# Out:
# <ipython-input-10-c8f82eff647f>:8: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   modelparams[i,:] = localmin, grad
# array([[0.735     , 1.5       ],
#        [0.7209    , 1.41      ],
#        [0.707646  , 1.3254    ],
#        [0.69518724, 1.245876  ],
#        [0.68347601, 1.17112344]])

# %%
# Plot the gradient over iterations
fig,ax = plt.subplots(1,2,figsize=(12,5))

for i in range(2):
  ax[i].plot(modelparams[:,i], "o-")
  ax[i].set_xlabel("Iteration")
  ax[i].set_title("Final Estimated Minimum: {:.3f}".format(localmin[0]))

ax[0].set_ylabel("Local Minimum")
ax[1].set_ylabel("Derivative")

plt.show()

# %%
# Lets change the learning rate and see what happens
localmin = np.random.choice(x,1)
# define learning parameters
learning_rate = 0.1
training_epochs = 100

# Lets store the parameters
modelparams = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad
  modelparams[i,:] = localmin, grad

# Plot the gradient over iterations
fig,ax = plt.subplots(1,2,figsize=(12,5))

for i in range(2):
  ax[i].plot(modelparams[:,i], "o-")
  ax[i].set_xlabel("Iteration")
  ax[i].set_title("Final Estimated Minimum: {:.3f}".format(localmin[0]))

ax[0].set_ylabel("Local Minimum")
ax[1].set_ylabel("Derivative")

plt.show()
# Out:
# <ipython-input-13-fc8fd950cdcd>:13: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   modelparams[i,:] = localmin, grad

# %%
# Lets change the learning rate and see what happens
localmin = np.random.choice(x,1)
# define learning parameters
learning_rate = 0.001
training_epochs = 100

# Lets store the parameters
modelparams = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad
  modelparams[i,:] = localmin, grad

# Plot the gradient over iterations
fig,ax = plt.subplots(1,2,figsize=(12,5))

for i in range(2):
  ax[i].plot(modelparams[:,i], "o-")
  ax[i].set_xlabel("Iteration")
  ax[i].set_title("Final Estimated Minimum: {:.3f}".format(localmin[0]))

ax[0].set_ylabel("Local Minimum")
ax[1].set_ylabel("Derivative")

plt.show()
# Out:
# <ipython-input-14-dc31440351f2>:13: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   modelparams[i,:] = localmin, grad

# %%
# Lets change the learning epoch number
localmin = np.random.choice(x,1)
# define learning parameters
learning_rate = 0.001
training_epochs = 1000

# Lets store the parameters
modelparams = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad
  modelparams[i,:] = localmin, grad

# Plot the gradient over iterations
fig,ax = plt.subplots(1,2,figsize=(12,5))

for i in range(2):
  ax[i].plot(modelparams[:,i], "o-")
  ax[i].set_xlabel("Iteration")
  ax[i].set_title("Final Estimated Minimum: {:.3f}".format(localmin[0]))

ax[0].set_ylabel("Local Minimum")
ax[1].set_ylabel("Derivative")

plt.show()
# Out:
# <ipython-input-15-244c9cf1861a>:13: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   modelparams[i,:] = localmin, grad

# %% [markdown]
# ### Additional Stuff

# %%
# 1) Most often in DL, the model trains for a set number of iterations, which is what we do here. But there are other ways
#    of defining how long the training lasts. Modify the code so that training ends when the derivative is smaller than 
#    some threshold, e.g., 0.1. Make sure your code is robust for negative derivatives.

# Lets change the learning epoch number
localmin = np.random.choice(x,1)
# define learning parameters
learning_rate = 0.01
training_epochs = 1000

# Lets store the parameters
modelparams = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad
  if abs(grad) < 0.1: # introduce the threshold
    break
  modelparams[i,:] = localmin, grad

# Modify the length of the array to avoid plotting zeros
modelparams = modelparams[np.where(abs(modelparams[:,1]) > 0)]

# Plot the gradient over iterations
fig,ax = plt.subplots(1,2,figsize=(12,5))

for i in range(2):
  ax[i].plot(modelparams[:,i], "o-")
  ax[i].set_xlabel("Iteration")
  ax[i].set_title("Final Estimated Minimum: {:.3f}".format(localmin[0]))

ax[0].set_ylabel("Local Minimum")
ax[1].set_ylabel("Derivative")

plt.show()
# Out:
# <ipython-input-16-314f5e7077a2>:19: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   modelparams[i,:] = localmin, grad

# %%
# 2) Does this change to the code produce a more accurate result? What if you change the stopping threshold?
# It increases the number of epochs

# Lets change the learning epoch number
localmin = np.random.choice(x,1)
# define learning parameters
learning_rate = 0.01
training_epochs = 1000

# Lets store the parameters
modelparams = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad
  if abs(grad) < 0.001: # introduce the threshold
    break
  modelparams[i,:] = localmin, grad

# Modify the length of the array to avoid plotting zeros
modelparams = modelparams[np.where(abs(modelparams[:,1]) > 0)]

# Plot the gradient over iterations
fig,ax = plt.subplots(1,2,figsize=(12,5))

for i in range(2):
  ax[i].plot(modelparams[:,i], "o-")
  ax[i].set_xlabel("Iteration")
  ax[i].set_title("Final Estimated Minimum: {:.3f}".format(localmin[0]))

ax[0].set_ylabel("Local Minimum")
ax[1].set_ylabel("Derivative")

plt.show()
# Out:
# <ipython-input-17-7c437e2abd98>:18: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   modelparams[i,:] = localmin, grad

# %% [markdown]
# ## Code Challenge: Unfortunate Starting Value

# %% [markdown]
# Goals of this challenge are divided in two steps
#
# Step 1: Repeat 1D GD to find the mnimum of the following function
#
# $f(x) = cos(2\pi x) + x^2, x \in \{-2,2\}$
#
# Step 2: Hard-code a starting value of x = 0

# %%
import sympy as sym
import sympy.plotting.plot as symplot

# %%
# create symbolic vaiables in sympy
x = sym.symbols("x")

# create a function
fx = sym.cos(2*np.pi*x) + x**2

# compute its derivative
df = sym.diff(fx,x)

print(fx)
print()
print(df)
# Out:
# x**2 + cos(6.28318530717959*x)
#
# 2*x - 6.28318530717959*sin(6.28318530717959*x)

# %%
p = symplot(fx,(x,-2,2), label="f(x)",show=False, lin_color="blue")
p.extend(symplot(df,(x,-2,2),label="df(x)",show=False,line_color="red"))
p.legend = True
p.show()

# %%
# Plot with matplotlib
def fx(x):
  return np.cos(2*np.pi*x) + x**2
# Copy the derivative from above
def deriv(x):
  return 2*x - 2*np.pi*np.sin(2*np.pi*x)

x = np.linspace(-2,2,2000)
plt.plot(x, fx(x), x, deriv(x))
plt.xlim([-2,2])
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend(["y", "dy"])
plt.show()

# %%
# Start with a random value
x = np.linspace(-2,2, 2000)
localmin = np.random.choice(x,1)
# define learning parameters
learning_rate = 0.01
training_epochs = 100

# Lets store the parameters
modelparams = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad

print(localmin)
# Out:
# [0.47580245]

# %%
plt.plot(x, fx(x), x, deriv(x))
plt.plot(localmin, deriv(localmin),"ro")
plt.plot(localmin, fx(localmin), "ro")
plt.xlim([-2,2])
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend(["f(x)", "df", "f(x) min"])
plt.title("Emipirical local minimum is {:.3f}".format(localmin[0]))
plt.show()

# %%
x = np.linspace(-2,2, 2000)
localmin = np.random.choice(x,1)
# define learning parameters
learning_rate = 0.01
training_epochs = 100

# Lets store the parameters
modelparams = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad
  modelparams[i,:] = localmin, grad

print(localmin)

# Plot the gradient over iterations
fig,ax = plt.subplots(1,2,figsize=(12,5))

for i in range(2):
  ax[i].plot(modelparams[:,i], "o-")
  ax[i].set_xlabel("Iteration")
  ax[i].set_title("Final Estimated Minimum: {:.3f}".format(localmin[0]))

ax[0].set_ylabel("Local Minimum")
ax[1].set_ylabel("Derivative")

plt.show()
# Out:
# <ipython-input-13-b84b881738a4>:13: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   modelparams[i,:] = localmin, grad
# [0.47580245]

# %%
# Hard code the beginning point to be exactly zero
localmin = np.array([0])
learning_rate = 0.01
training_epochs = 100
for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad
print(localmin)
# The algorithm is stuck at zero because of the derivative. It thinks it has already discovered the global minimum, and in this way we are tricking gradient descentg
# This is a case of vanishing gradient which will be seen later in the course
# Out:
# [0.]

# %%
plt.plot(x, fx(x), x, deriv(x))
plt.plot(localmin, deriv(localmin),"ro")
plt.plot(localmin, fx(localmin), "ro")
plt.xlim([-2,2])
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend(["f(x)", "df", "f(x) min"])
plt.title("Emipirical local minimum is {:.3f}".format(localmin[0]))
plt.show()

# %% [markdown]
# #### Some Additional Explorations

# %%
# Hard-code the initial value at a small value, say 0.01. Now we expect it to move to a local minimum (or global in this case)
# The value doesnt change
localmin = np.array([0.0001])
learning_rate = 0.01
training_epochs = 100
for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad
print(localmin)
# Out:
# [0.47580245]

# %%
plt.plot(x, fx(x), x, deriv(x))
plt.plot(localmin, deriv(localmin),"ro")
plt.plot(localmin, fx(localmin), "ro")
plt.xlim([-2,2])
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend(["f(x)", "df", "f(x) min"])
plt.title("Emipirical local minimum is {:.3f}".format(localmin[0]))
plt.show()

# %%
# Remove the 2 multiplicative factor from the expression and see what happens
def fx(x):
  return np.cos(np.pi*x) + x**2
# Copy the derivative from above
def deriv(x):
  return 2*x - np.pi*np.sin(np.pi*x)

x = np.linspace(-2,2,2000)
plt.plot(x, fx(x), x, deriv(x))
plt.xlim([-2,2])
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend(["y", "dy"])
plt.show()
# The function is flatter, only two possible minima, and they are the same, just sign diffferences

# %%
x = np.linspace(-2,2, 2000)
localmin = np.random.choice(x,1)
learning_rate = 0.01
training_epochs = 100
for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - learning_rate*grad
print(localmin)
# Out:
# [-0.82415995]

# %%
plt.plot(x, fx(x), x, deriv(x))
plt.plot(localmin, deriv(localmin),"ro")
plt.plot(localmin, fx(localmin), "ro")
plt.xlim([-2,2])
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend(["f(x)", "df", "f(x) min"])
plt.title("Emipirical local minimum is {:.3f}".format(localmin[0]))
plt.show()

# %% [markdown]
# ## Gradient Descent in 2D

# %%
# We will use the peaks function, he logo of matlab
def peaks(x,y):
  # expand to a 2D mesh
  x,y = np.meshgrid(x,y)
  z = (3*(1-x)**2*np.exp(-(x**2)-(y+1)**2) 
      - 10*(x/5-x**3-y**5)*np.exp(-x**2-y**2)
      - 1/3*np.exp(-(x+1)**2-y**2))
  return z

# %%
# create the landscape
x = np.linspace(-3,3,201)
y = np.linspace(-3,3,201)

Z = peaks(x,y)

plt.imshow(Z, extent=[x[0],x[-1],y[0],y[-1]],vmin=-5, vmax=5, origin="lower")
plt.colorbar()
plt.show()

# %%
# Derivtives with Sympy
sx,sy = sym.symbols("sx,sy")

sZ = (3*(1-sx)**2*sym.exp(-(sx**2)-(sy+1)**2) 
      - 10*(sx/5-sx**3-sy**5)*sym.exp(-sx**2-sy**2)
      - 1/3*sym.exp(-(sx+1)**2-sy**2))

# Create functions from sympy-computed derivative
df_x = sym.lambdify((sx,sy), sym.diff(sZ,sx), "sympy")
df_y = sym.lambdify((sx,sy), sym.diff(sZ,sy), "sympy")

df_x(1,1).evalf()
# Out:
# -1.07369833656079

# %%
# Pick a andom startig point between -2 to 2
localmin = np.random.rand(2)*4 - 2
startpoint = localmin[:] # make a copy without reasigning

# define the learning parameters
learning_rate = 0.01
training_epochs = 100

trajectory = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = np.array([df_x(localmin[0], localmin[1]).evalf(),
                   df_y(localmin[0], localmin[1]).evalf()])
  localmin = localmin - learning_rate*grad
  trajectory[i,:] = localmin

print(localmin)
print(startpoint)
# Out:
# [0.296417179847959 0.320387112168083]
# [0.75965193 0.48614418]

# %%
plt.imshow(Z, extent=[x[0],x[-1],y[0],y[-1]],vmin=-5, vmax=5, origin="lower")
plt.plot(startpoint[0], startpoint[1], "bs")
plt.plot(localmin[0], localmin[1], "ro")
plt.plot(trajectory[:,0], trajectory[:,1], "r")
plt.legend(["rnd start", "local min"])
plt.colorbar()
plt.show()

# %% [markdown]
# ### Additional Exploration

# %%
# Force the intial guess to be [0, 1.4]
# Pick a andom startig point between -2 to 2
localmin = np.array([0, 1.4])
startpoint = localmin[:] # make a copy without reasigning

# define the learning parameters
learning_rate = 0.01
training_epochs = 100

trajectory = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = np.array([df_x(localmin[0], localmin[1]).evalf(),
                   df_y(localmin[0], localmin[1]).evalf()
                   ])
  localmin = localmin - learning_rate*grad
  trajectory[i,:] = localmin

plt.imshow(Z, extent=[x[0],x[-1],y[0],y[-1]],vmin=-5, vmax=5, origin="lower")
plt.plot(startpoint[0], startpoint[1], "bs")
plt.plot(localmin[0], localmin[1], "ro")
plt.plot(trajectory[:,0], trajectory[:,1], "r")
plt.legend(["rnd start", "local min"])
plt.colorbar()
plt.show()

# %%
# Change the learning rate to 0.1, then 0.5
# Force the intial guess to be [0, 1.4]
localmin = np.array([0, 1.4])
startpoint = localmin[:] # make a copy without reasigning

# define the learning parameters
learning_rate = 0.5
training_epochs = 1000

trajectory = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = np.array([df_x(localmin[0], localmin[1]).evalf(),
                   df_y(localmin[0], localmin[1]).evalf()
                   ])
  localmin = localmin - learning_rate*grad
  trajectory[i,:] = localmin

plt.imshow(Z, extent=[x[0],x[-1],y[0],y[-1]],vmin=-5, vmax=5, origin="lower")
plt.plot(startpoint[0], startpoint[1], "bs")
plt.plot(localmin[0], localmin[1], "ro")
plt.plot(trajectory[:,0], trajectory[:,1], "r")
plt.legend(["rnd start", "local min"])
plt.colorbar()
plt.show()

# %%
# Change the learning rate to 0.1, then 0.01
# Force the intial guess to be [0, 1.4]
localmin = np.array([0, 1.4])
startpoint = localmin[:] # make a copy without reasigning

# define the learning parameters
learning_rate = 0.1
training_epochs = 1000

trajectory = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = np.array([df_x(localmin[0], localmin[1]).evalf(),
                   df_y(localmin[0], localmin[1]).evalf()
                   ])
  localmin = localmin - learning_rate*grad
  trajectory[i,:] = localmin

plt.imshow(Z, extent=[x[0],x[-1],y[0],y[-1]],vmin=-5, vmax=5, origin="lower")
plt.plot(startpoint[0], startpoint[1], "bs")
plt.plot(localmin[0], localmin[1], "ro")
plt.plot(trajectory[:,0], trajectory[:,1], "r")
plt.legend(["rnd start", "local min"])
plt.colorbar()
plt.show()

# %%
# Change the learning rate to 0.005
# Force the intial guess to be [0, 0]
localmin = np.array([0, 0])
startpoint = localmin[:] # make a copy without reasigning

# define the learning parameters
learning_rate = 0.005
training_epochs = 1000

trajectory = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = np.array([df_x(localmin[0], localmin[1]).evalf(),
                   df_y(localmin[0], localmin[1]).evalf()
                   ])
  localmin = localmin - learning_rate*grad
  trajectory[i,:] = localmin

plt.imshow(Z, extent=[x[0],x[-1],y[0],y[-1]],vmin=-5, vmax=5, origin="lower")
plt.plot(startpoint[0], startpoint[1], "bs")
plt.plot(localmin[0], localmin[1], "ro")
plt.plot(trajectory[:,0], trajectory[:,1], "r")
plt.legend(["rnd start", "local min"])
plt.colorbar()
plt.show()

# %%
print(localmin)
# Out:
# [0.296445553846833 0.320196247666828]

# %% [markdown]
# ## Code Challenge: 2D Gradient Ascent

# %% [markdown]
# Modify the 2D Gradient Descent code to perform gradient ascent and find the local maximum

# %%
# FIRST SOLUTION IS TO CHANGE GRADIENT SIGN
# (either -np.array(....), or add a plus before localmin*grad)
localmin = np.random.rand(2)*4-2
startpoint = localmin[:] # make a copy without reasigning

# define the learning parameters
learning_rate = 0.01
training_epochs = 100

trajectory = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = np.array([df_x(localmin[0], localmin[1]).evalf(),
                   df_y(localmin[0], localmin[1]).evalf()
                   ])
  localmin = localmin + learning_rate*grad
  trajectory[i,:] = localmin

plt.imshow(Z, extent=[x[0],x[-1],y[0],y[-1]],vmin=-5, vmax=5, origin="lower")
plt.plot(startpoint[0], startpoint[1], "bs")
plt.plot(localmin[0], localmin[1], "ro")
plt.plot(trajectory[:,0], trajectory[:,1], "r")
plt.legend(["rnd start", "local min"])
plt.colorbar()
plt.show()

# %%
# the second method is to flip the sign of the derivative
sx,sy = sym.symbols("sx,sy")

sZ = (3*(1-sx)**2*sym.exp(-(sx**2)-(sy+1)**2) 
      - 10*(sx/5-sx**3-sy**5)*sym.exp(-sx**2-sy**2)
      - 1/3*sym.exp(-(sx+1)**2-sy**2))

# Create functions from sympy-computed derivative
df_xa = sym.lambdify((sx,sy), sym.diff(-sZ,sx), "sympy")
df_ya = sym.lambdify((sx,sy), sym.diff(-sZ,sy), "sympy")

# it will flip sign (double-checking)
df_xa(1,1).evalf()
# Out:
# 1.07369833656079

# %%
localmin = np.random.rand(2)*4-2
startpoint = localmin[:] # make a copy without reasigning

# define the learning parameters
learning_rate = 0.01
training_epochs = 100

trajectory = np.zeros((training_epochs,2))

for i in range(training_epochs):
  grad = np.array([df_xa(localmin[0], localmin[1]).evalf(),
                   df_ya(localmin[0], localmin[1]).evalf()
                   ])
  localmin = localmin - learning_rate*grad
  trajectory[i,:] = localmin

plt.imshow(Z, extent=[x[0],x[-1],y[0],y[-1]],vmin=-5, vmax=5, origin="lower")
plt.plot(startpoint[0], startpoint[1], "bs")
plt.plot(localmin[0], localmin[1], "ro")
plt.plot(trajectory[:,0], trajectory[:,1], "r")
plt.legend(["rnd start", "local min"])
plt.colorbar()
plt.show()

# %% [markdown]
# ## Parametric Experiments on Gradient Descent

# %% [markdown]
# Understanding the importance of starting values, learning rate and number of training iterations in gradient descent
#
# Three experiemtns here:
#
# One-variable experiement using:
#
# a) Initial value
#
# b) Constant Initial value, different learning rate
#
# A two-variable experiment using learning rate and training epochs

# %%
# compute the derivative first
from sympy import sin, cos, diff, exp
x = sym.symbols("x")
fx = sin(x)*exp(-x**2*0.05)
df = diff(fx,x)
print(df)
# Out:
# -0.1*x*exp(-0.05*x**2)*sin(x) + exp(-0.05*x**2)*cos(x)

# %%
# define the range
x = np.linspace(-2*np.pi, 2*np.pi, 401)
# Function in numpy formt
fx = np.sin(x)*np.exp(-x**2*0.05)
# write the derivative
df = np.exp(-0.05*x**2)*np.cos(x) + np.sin(x)*np.exp(-0.05*x**2)*(-0.1*x)

# plot
plt.plot(x, fx, x, df)
plt.legend(["f(x)", "df"])
plt.grid()
plt.show()

# %%
# Write functional forms 
def fx(x):
  return np.sin(x)*np.exp(-x**2*0.05)

def deriv(x):
  return np.exp(-0.05*x**2)*np.cos(x) + np.sin(x)*np.exp(-0.05*x**2)*(-0.1*x)

# %%
# random starting point
localmin = np.random.choice(x,1)
print(localmin)

# learning parameters
learning_rate = 0.01
training_epochs = 100

for i in range(training_epochs):
  grad = deriv(localmin)
  localmin = localmin - grad*learning_rate
#print(localmin)
# plot the whole thing
plt.plot(x, fx(x), x, deriv(x), "--")
plt.plot(localmin, deriv(localmin), "ro")
plt.plot(localmin, fx(localmin), "ro")
plt.legend(["fx", "df", "min fx"])
plt.title("Empirical local minimum: {:.3f}".format(localmin[0]))
plt.grid()
plt.show()
# Out:
# [-5.46637122]

# %% [markdown]
# ### Run Parametric Experiments

# %% [markdown]
# #### Experiment 1: Varying Starting Points

# %%
# Experiment 1: Systematically Vary the starting locaions
x = np.linspace(-2*np.pi, 2*np.pi, 401)
localmin = np.random.choice(x,1)

# learning parameters
learning_rate = 0.01
training_epochs = 1000

startlocs = np.linspace(-5,5,50)
finalres = np.zeros(len(startlocs))

# Loop over the stating points
for idx,localmin in enumerate(startlocs):

  # Training
  for i in range(training_epochs):
    grad = deriv(localmin)
    localmin = localmin - grad*learning_rate
  
  # Store the final value
  finalres[idx] = localmin

# Plot
plt.plot(startlocs, finalres, "s-")
plt.xlabel("Starting Guess")
plt.ylabel("Final Guess")
plt.plot()
# Out:
# []

# %% [markdown]
# #### Experiment 2: Change the Learning Rate

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 401)

# define a range of learning rates
learning_rates = np.linspace(1e-10, 1e-1, 50)
finalres = np.zeros(len(learning_rates))
training_epochs = 1000

# loop over the learning rates
for idx, learningRate in enumerate(learning_rates):

  # force-start at 0
  localmin = 0

  # run through training
  for i in range(training_epochs):
    grad = deriv(localmin)
    localmin = localmin - learningRate*grad

  finalres[idx] = localmin

plt.plot(learning_rates, finalres, "s-")
plt.xlabel("Learning Rate")
plt.ylabel("Final Guess")
plt.show()

# %%
plt.plot(learning_rates, finalres, "s-")
plt.xlabel("Learning Rate")
plt.ylabel("Final Guess")
plt.xlim([1e-10, 1e-2])
plt.show()

# %% [markdown]
# #### Experiment 3: Interaction of Learning Rate & Training Epochs

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 401)

# define a range of learning rates
learning_rates = np.linspace(1e-10, 1e-1, 50)
training_epochs = np.round(np.linspace(10, 500, 40))

finalres = np.zeros((len(learning_rates), len(training_epochs)))

# Loop over learning rates
for Lidx, learningRate in enumerate(learning_rates):
    # Loop over training epochs
    for Eidx, trainEpochs in enumerate(training_epochs):

        # Run through the training
        localmin = 0
        for i in range(int(trainEpochs)):
            grad = deriv(localmin)
            localmin = localmin - grad*learningRate
        
        # Store the final guess
        finalres[Lidx,Eidx] = localmin

# %%
# Plot the whole thing
fig, ax = plt.subplots(figsize=(7,5))
plt.imshow(finalres, extent=[learning_rates[0], learning_rates[-1],training_epochs[0], training_epochs[-1]],
           aspect = "auto", origin="lower", vmin=-1.45, vmax = -1.2)
plt.xlabel("Learning Rate")
plt.ylabel("Training Epochs")
plt.title("Learning Rate and Training Epoch Interaction")
plt.colorbar()
plt.show()

# Another visualization
plt.plot(learning_rates, finalres)
plt.xlabel("Learning Rate")
plt.ylabel("Final Function Eastimate")
plt.title("Each Line Represents a Training Epoch")
plt.show()

# %% [markdown]
# ##### Some Additional Explorations

# %%
# Set the starting point to be 1.6 and see what happens
# Reverse of previous case
x = np.linspace(-2*np.pi, 2*np.pi, 401)

# define a range of learning rates
learning_rates = np.linspace(1e-10, 1e-1, 50)
training_epochs = np.round(np.linspace(10, 500, 40))

finalres = np.zeros((len(learning_rates), len(training_epochs)))

# Loop over learning rates
for Lidx, learningRate in enumerate(learning_rates):
    # Loop over training epochs
    for Eidx, trainEpochs in enumerate(training_epochs):

        # Run through the training
        localmin = 1.6
        for i in range(int(trainEpochs)):
            grad = deriv(localmin)
            localmin = localmin - grad*learningRate
        
        # Store the final guess
        finalres[Lidx,Eidx] = localmin

# Plot the whole thing
fig, ax = plt.subplots(figsize=(7,5))
plt.imshow(finalres, extent=[learning_rates[0], learning_rates[-1],training_epochs[0], training_epochs[-1]],
           aspect = "auto", origin="lower")
plt.xlabel("Learning Rate")
plt.ylabel("Training Epochs")
plt.title("Learning Rate and Training Epoch Interaction")
plt.colorbar()
plt.show()

# Another visualization
plt.plot(learning_rates, finalres)
plt.xlabel("Learning Rate")
plt.ylabel("Final Function Eastimate")
plt.title("Each Line Represents a Training Epoch")
plt.show()

# %%
# Start Randomly: Converges better
x = np.linspace(-2*np.pi, 2*np.pi, 401)
localmin = np.random.choice(x,1)
print(localmin)

# define a range of learning rates
learning_rates = np.linspace(1e-10, 1e-1, 50)
training_epochs = np.round(np.linspace(10, 500, 40))

finalres = np.zeros((len(learning_rates), len(training_epochs)))

# Loop over learning rates
for Lidx, learningRate in enumerate(learning_rates):
    # Loop over training epochs
    for Eidx, trainEpochs in enumerate(training_epochs):

        # Run through the training
        # localmin = 1.6
        for i in range(int(trainEpochs)):
            grad = deriv(localmin)
            localmin = localmin - grad*learningRate
        
        # Store the final guess
        finalres[Lidx,Eidx] = localmin

# Plot the whole thing
fig, ax = plt.subplots(figsize=(7,5))
plt.imshow(finalres, extent=[learning_rates[0], learning_rates[-1],training_epochs[0], training_epochs[-1]],
           aspect = "auto", origin="lower")
plt.xlabel("Learning Rate")
plt.ylabel("Training Epochs")
plt.title("Learning Rate and Training Epoch Interaction")
plt.colorbar()
plt.show()

# Another visualization
plt.plot(learning_rates, finalres)
plt.xlabel("Learning Rate")
plt.ylabel("Final Function Eastimate")
plt.title("Each Line Represents a Training Epoch")
plt.show()
# Out:
# [-1.41371669]

# %% [markdown]
# ## Code Challenge: Fixed vs Dynamic Learning Rate

# %% [markdown]
# Explore ways of changing the learning rate: i.e., it will change at each iteration of the GD.

# %%
# We will use the simple function of 1D GD
x = np.linspace(-2,2,2001)

def fx(x):
    return 3*x**2 - 3*x + 4

def deriv(x):
    return 6*x - 3

plt.plot(x,fx(x), x, deriv(x))
plt.xlim([-2,2])
plt.legend(["f(x)", "df"])
plt.grid()
plt.show()

# %% [markdown]
# ### GD with fixed learning rate

# %%
localmin = np.random.choice(x,1)
print(localmin)

initval = localmin[:]

learning_rate = 0.01
training_epochs = 50

modelparamsFixed = np.zeros((training_epochs, 3))

for i in range(training_epochs):

    # gradient
    grad = deriv(localmin)

    # non-adaptive learning rate (set-up for lr modification)
    lr = learning_rate

    # update the parameter
    localmin = localmin - grad*lr

    # store
    modelparamsFixed[i,:] = localmin, grad, lr
# Out:
# [0.03]
# <ipython-input-37-ae98ca9db8c0>:23: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   modelparamsFixed[i,:] = localmin, grad, lr

# %% [markdown]
# ### Gradient-Based Learning Rate

# %%
localmin = np.random.choice(x,1)
print(localmin)

initval = localmin[:]

learning_rate = 0.01
training_epochs = 50

modelparamsGrad = np.zeros((training_epochs, 3))

for i in range(training_epochs):

    # gradient
    grad = deriv(localmin)

    # Scale the learning rate by the gradient
    lr = learning_rate*np.abs(grad)

    # update the parameter
    localmin = localmin - grad*lr

    # store
    modelparamsGrad[i,:] = localmin, grad, lr
# Out:
# [-1.912]
# <ipython-input-38-ea8a780a69fe>:23: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   modelparamsGrad[i,:] = localmin, grad, lr

# %% [markdown]
# ### GD Dynamic: Time-based Learning Rate

# %%
# redefine the parameters
localmin = np.random.choice(x,1)
print(localmin)

initval = localmin[:]

training_epochs = 50

learning_rate = 0.1
localmin = initval

# Run through training and store all the results
modelparamsTime = np.zeros((training_epochs, 3))

for i in range(training_epochs):
    
    grad = deriv(localmin)
    
    # lr will decrease as learning epochs increase
    lr = learning_rate*(1-(i+1)/training_epochs)

    localmin = localmin - lr*grad

    modelparamsTime[i,:] = localmin, grad, lr
# Out:
# [0.194]
# <ipython-input-40-9af96b9534bb>:24: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   modelparamsTime[i,:] = localmin, grad, lr

# %%
# Plot
fig,ax = plt.subplots(1,3, figsize=(10,3))

for i in range(3):
    ax[i].plot(modelparamsFixed[:,i], "o-", markerfacecolor="w")
    ax[i].plot(modelparamsGrad[:,i], "o-", markerfacecolor="w")
    ax[i].plot(modelparamsTime[:,i], "o-", markerfacecolor="w")
    ax[i].set_xlabel("Iteration")

ax[0].set_ylabel("Local Minimum")
ax[1].set_ylabel("Derivative")
ax[2].set_ylabel("Learning Rate")
ax[2].legend(["Fixed lr", "Grad-Based lr", "Time-Based lr"])

plt.tight_layout()
plt.show()

# %%
# Start at the same initial point
localmin = -2

learning_rate = 0.01
training_epochs = 50

modelparamsGrad = np.zeros((training_epochs, 3))

for i in range(training_epochs):

    # gradient
    grad = deriv(localmin)

    # Scale the learning rate by the gradient
    lr = learning_rate*np.abs(grad)

    # update the parameter
    localmin = localmin - grad*lr

    # store
    modelparamsGrad[i,:] = localmin, grad, lr

modelparamsGrad = np.zeros((training_epochs, 3))

for i in range(training_epochs):

    # gradient
    grad = deriv(localmin)

    # Scale the learning rate by the gradient
    lr = learning_rate*np.abs(grad)

    # update the parameter
    localmin = localmin - grad*lr

    # store
    modelparamsGrad[i,:] = localmin, grad, lr

modelparamsTime = np.zeros((training_epochs, 3))

for i in range(training_epochs):
    
    grad = deriv(localmin)
    
    # lr will decrease as learning epochs increase
    lr = learning_rate*(1-(i+1)/training_epochs)

    localmin = localmin - lr*grad

    modelparamsTime[i,:] = localmin, grad, lr

# Plot
fig,ax = plt.subplots(1,3, figsize=(10,3))

for i in range(3):
    ax[i].plot(modelparamsFixed[:,i], "o-", markerfacecolor="w")
    ax[i].plot(modelparamsGrad[:,i], "o-", markerfacecolor="w")
    ax[i].plot(modelparamsTime[:,i], "o-", markerfacecolor="w")
    ax[i].set_xlabel("Iteration")

ax[0].set_ylabel("Local Minimum")
ax[1].set_ylabel("Derivative")
ax[2].set_ylabel("Learning Rate")
ax[2].legend(["Fixed lr", "Grad-Based lr", "Time-Based lr"])

plt.tight_layout()
plt.show()
